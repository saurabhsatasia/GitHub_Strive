# %% [markdown]
# # Let's test your implementation of LinearRegression

# %%
# Import your class here:
file = 01_linear_regression_from_scratch
from file import Linear_Regression
# Out:
#   File "<ipython-input-4-de354c4eec63>", line 2
#     file = 01_linear_regression_from_scratch
#              ^
# SyntaxError: invalid decimal literal

# %%
assert LinearRegression is not None, 'You should import your class'
assert 'fit' in dir(LinearRegression) and 'predict' in dir(LinearRegression), 'You should follow sklearn conventions'

# %%
# Load the data in X and y
class Linear_Regression:

    def __init__(self):
        self.intercept_c_a = 0
        self.slope_m_b = 0

    def fit(self, X, y):
        # slope and intercept 
        self.slope_m_b = np.sum(( X - np.mean(X)) * (y - np.mean(y))) / np.sum(np.square(X - np.mean(X)))
        self.intercept_c_a = np.mean(y) - (self.slope_m_b * np.mean(X))
        return self #.slope_m_b, self.intercept_c_a
    
    def predict(self, X):
        self.y_pred = self.slope_m_b*X + self.intercept_c_a
        return self.y_pred

    def plot(self,X,y):
        sns.scatterplot(X, y)
        sns.lineplot(x=X, y=(self. intercept_c_a+self.slope_m_b*X), color='red')
        plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#load and inspect the data
df = pd.read_csv("reg_data.csv", header=None)
df.rename(columns = {0:"x", 1:"y"}, inplace=True)

X = df['x'].values  #.reshape(-1,1)
y = df['y'].values

# %%
assert X is not None and type(X) == np.ndarray, 'X should be defined and be a numpy array'
assert y is not None and type(y) == np.ndarray, 'y should be defined and be a numpy array'

# %% [markdown]
# # Plot x against y using matplotlib
#
# example:
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Scatter_diagram_for_quality_characteristic_XXX.svg/1200px-Scatter_diagram_for_quality_characteristic_XXX.svg.png" alt="drawing" width="300"/>

# %%
# Code to plot X vs y
plt.scatter(X,y)

# %% [markdown]
# # Fit the model

# %%
model = Linear_Regression().fit(X, y)

# %%
assert model is not None and type(model) == Linear_Regression, 'Fit method should return itself'

# %% [markdown]
# # Plot the line generated by your model
# example:
# <img src="https://howtothink.readthedocs.io/en/latest/_images/mpl_basic.png" alt="drawing" width="300"/>

# %%
import seaborn as sns
# Code to plot X vs H(X)
sns.lineplot(x=X, y=(model.intercept_c_a + model.slope_m_b * X))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Plot the line generated by your model together with the scatter
# example:
# <img src="https://i.stack.imgur.com/DjuGW.png" alt="drawing" width="300"/>

# %%
# Code to plot X vs H(X) and X vs y
model.plot(X,y)
# Out:
# C:\Users\Saurabh\anaconda3\envs\test\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
